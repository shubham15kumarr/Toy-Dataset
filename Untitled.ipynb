# %%
# !pip install mlxtend
import numpy as np

import pandas as pd
# Out:
# Requirement already satisfied: mlxtend in c:\users\shubh\downloads\my code\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\shubh\downloads\my code\lib\site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\shubh\downloads\my code\lib\site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\shubh\downloads\my code\lib\site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\shubh\downloads\my code\lib\site-packages (from mlxtend) (1.7.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\shubh\downloads\my code\lib\site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\shubh\downloads\my code\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shubh\downloads\my code\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shubh\downloads\my code\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shubh\downloads\my code\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shubh\downloads\my code\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shubh\downloads\my code\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shubh\downloads\my code\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shubh\downloads\my code\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shubh\downloads\my code\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shubh\downloads\my code\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shubh\downloads\my code\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shubh\downloads\my code\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\shubh\downloads\my code\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
df=pd.read_csv('placement.csv')

# %%
print(df)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df= df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df ['cgpa'],df ['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     Unnamed: 0  cgpa
# 0            0   6.8
# 1            1   5.9
# 2            2   5.3
# 3            3   7.4
# 4            4   5.8
# ..         ...   ...
# 95          95   4.3
# 96          96   4.4
# 97          97   6.7
# 98          98   6.3
# 99          99   6.2
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     Unnamed: 0  cgpa
# 58          58   8.0
# 52          52   7.0
# 60          60   6.9
# 78          78   6.1
# 20          20   6.6
# ..         ...   ...
# 16          16   5.2
# 42          42   7.6
# 15          15   5.1
# 40          40   4.9
# 45          45   6.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     Unnamed: 0  cgpa
# 28          28   5.2
# 72          72   7.3
# 71          71   6.1
# 44          44   7.5
# 25          25   5.0
# 75          75   4.8
# 53          53   8.3
# 76          76   4.9
# 3            3   7.4
# 68          68   4.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train= scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.29744442,  1.8233191 ],
#        [ 0.09283297,  0.91869551],
#        [ 0.36564823,  0.82823315],
#        [ 0.97948257,  0.10453428],
#        [-0.99842808,  0.55684607],
#        [-1.64636433, -0.07639044],
#        [ 1.66152073,  0.285459  ],
#        [ 1.32050165, -1.43332582],
#        [-1.50995669,  1.00915787],
#        [-0.28228801, -0.52870223],
#        [-0.55510328,  0.01407192],
#        [-0.41869565,  1.91378145],
#        [ 0.43385205,  0.01407192],
#        [ 1.18409402, -0.25731515],
#        [-0.96432617,  1.00915787],
#        [-1.1007338 , -2.42841176],
#        [-1.61226242, -0.61916459],
#        [-0.62330709, -1.88563761],
#        [ 0.57025968,  0.82823315],
#        [-1.68046623,  0.73777079],
#        [ 1.25229784, -0.80008931],
#        [ 0.53615777,  1.91378145],
#        [-0.93022426, -0.98101402],
#        [-0.45279755, -0.25731515],
#        [-0.69151091,  0.91869551],
#        [-1.37354906, -0.80008931],
#        [ 1.35460356, -0.98101402],
#        [ 0.60436159, -0.89055166],
#        [-0.657409  ,  1.46146966],
#        [ 1.1158902 ,  0.46638372],
#        [ 1.14999211,  1.3710073 ],
#        [-0.2140842 ,  0.73777079],
#        [-0.75971472,  0.01407192],
#        [ 0.6725654 ,  2.27563089],
#        [ 0.33154633, -1.07147638],
#        [ 1.55921501, -1.52378818],
#        [-1.27124334, -0.52870223],
#        [ 1.45690928, -0.70962695],
#        [-1.44175288, -0.89055166],
#        [-0.79381663,  0.91869551],
#        [ 0.05873106, -1.07147638],
#        [-1.30534525,  0.82823315],
#        [-0.00947275, -0.52870223],
#        [ 0.26334251,  0.46638372],
#        [-1.47585479, -0.25731515],
#        [ 0.84307494,  0.64730843],
#        [ 0.70666731,  0.285459  ],
#        [ 1.21819593, -0.16685279],
#        [-1.03252999, -0.70962695],
#        [-0.11177848, -0.61916459],
#        [ 1.49101119,  0.73777079],
#        [-1.20303952,  0.10453428],
#        [-0.58920518,  0.91869551],
#        [-0.52100137, -1.07147638],
#        [ 1.28639974, -0.25731515],
#        [ 1.42280737,  1.3710073 ],
#        [-1.33944716,  0.01407192],
#        [ 1.69562264,  0.19499664],
#        [ 1.04768639, -0.98101402],
#        [ 1.0817883 , -0.52870223],
#        [-0.38459374,  0.46638372],
#        [ 1.01358448,  0.46638372],
#        [ 0.46795396,  0.285459  ],
#        [-1.5440586 , -0.16685279],
#        [-1.23714143,  0.37592136],
#        [ 0.19513869,  1.64239438],
#        [ 0.80897303, -0.98101402],
#        [-1.06663189, -1.79517525],
#        [ 1.59331691, -1.43332582],
#        [ 0.50205586,  0.91869551],
#        [ 1.5251131 , -1.16193874],
#        [-0.48689946,  0.73777079],
#        [ 1.38870547,  1.19008259],
#        [ 0.16103679,  0.37592136],
#        [-0.89612235, -1.16193874],
#        [-0.86202045, -1.16193874],
#        [ 0.2292406 ,  0.10453428],
#        [ 0.94538067,  1.19008259],
#        [-1.40765097,  0.10453428],
#        [ 0.39975014,  1.19008259],
#        [-0.07767657, -0.70962695],
#        [ 1.62741882,  0.64730843],
#        [ 0.02462916, -2.24748704],
#        [-0.04357466,  0.55684607],
#        [-0.35049183, -1.2524011 ],
#        [-1.13483571, -0.70962695],
#        [-0.24818611,  1.46146966],
#        [-1.16893762, -0.80008931],
#        [-0.31638992, -0.98101402],
#        [-0.14588038,  0.01407192]])

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-0.96825953, -0.60924465],
#        [ 0.84465193,  0.89594801],
#        [ 0.8034494 ,  0.03583792],
#        [-0.309019  ,  1.03929969],
#        [-1.09186713, -0.75259633],
#        [ 0.96825953, -0.89594801],
#        [ 0.0618038 ,  1.61270642],
#        [ 1.00946207, -0.82427217],
#        [-1.99832287,  0.96762385],
#        [ 0.6798418 , -1.46935474]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf= LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 28    0
# 72    1
# 71    1
# 44    1
# 25    0
# 75    0
# 53    1
# 76    0
# 3     1
# 68    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions (x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
